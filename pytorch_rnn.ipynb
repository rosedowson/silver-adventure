# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
input_size=50
hidden_size=30
output_size=1
inputs=torch.rand(5,7,input_size)
targets=torch.rand(5,output_size)
learning_rate=0.001
class rnn(nn.Module):
    def __init__(self,input_size,hidden_size,output_size):
        super(rnn,self).__init__()
        self.rnn=nn.RNN(input_size,hidden_size,batch_first=True)
        self.linear=nn.Linear(hidden_size,output_size)
    def forward(self,x):
        h0=torch.zeros(1,x.size(0),hidden_size)
        out,_=self.rnn(x,h0)
        out=self.linear(out[:,-1,:])
        return out
model=rnn(input_size,hidden_size,output_size)

criterion=nn.MSELoss()
optimizer=torch.optim.Adam(model.parameters(),lr=learning_rate)

num_epochs=100
for epoch in range(num_epochs):
    outputs=model(inputs)
    loss=criterion(outputs,targets)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 10==0:
        print(f"epoch {epoch} loss = {loss.item():.3f}")

with torch.no_grad():

    inputs_test=torch.rand(5,7,input_size)
    outputs=model(inputs_test)
    print(f"test_output = {outputs}")
# Out:
# epoch 0 loss = 0.893
# epoch 10 loss = 0.055
# epoch 20 loss = 0.066
# epoch 30 loss = 0.019
# epoch 40 loss = 0.010
# epoch 50 loss = 0.004
# epoch 60 loss = 0.001
# epoch 70 loss = 0.000
# epoch 80 loss = 0.000
# epoch 90 loss = 0.000
# test_output = tensor([[0.4497],
#         [0.5876],
#         [0.5249],
#         [0.5644],
#         [0.4563]])
